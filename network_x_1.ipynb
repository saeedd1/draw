# %% [markdown]
# <a href="https://colab.research.google.com/github/saeedd1/draw/blob/main/network_x_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
G = nx.barabasi_albert_graph(100,2)

# %%
nx.draw_spring(G);

# %%
plt.hist([v for k,v in nx.degree(G)]);

# %%
plt.hist(nx.centrality.closeness_centrality(G).values());

# %%
nx.diameter(G)
# Out:
# 5

# %%
nx.cluster.average_clustering(G)
# Out:
# 0.06373523260365366

# %%
nodes = list(range(100))

df = pd.DataFrame({'from': np.random.choice(nodes, 100),
                   'to': np.random.choice(nodes,100)
                  })

# %%
df
# Out:
#     from  to
# 0     83  41
# 1     93  20
# 2     78  38
# 3     17  96
# 4     53  89
# ..   ...  ..
# 95    78   4
# 96    70  34
# 97    30  96
# 98    49   5
# 99    11  66
#
# [100 rows x 2 columns]

# %%
G = nx.from_pandas_edgelist(df, source='from', target='to')

# %%
nx.draw(G);

# %%
plt.hist([v for k,v in nx.degree(G)]);
